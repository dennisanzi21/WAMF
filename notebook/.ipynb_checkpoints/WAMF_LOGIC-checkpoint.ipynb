# %% [markdown]
# # Weather Info (temperature, weather, humidity and windspeed)

# %% [markdown]
# To obtain dummy weather information.

# %%
# To obtain weather data 
import requests
import os
from datetime import datetime
#user_api = os.environ['	weather']
api_key = '46eb4ea0e8fadb82e97f406034d68ce5'
city_name = input("Enter the city name: ")

complete_api_link = "https://api.openweathermap.org/data/2.5/weather?q="+city_name+"&appid="+api_key
api_link = requests.get(complete_api_link)
api_data = api_link.json()

if api_data['cod'] == '404':
    print("Invalid City: {}, Please check your City name".format(city_name))
else:
    #create variables to store and display data
    temp_city = ((api_data['main']['temp']) - 273.15)
    weather_desc = api_data['weather'][0]['description']
    hmdt = api_data['main']['humidity']
    wind_spd = api_data['wind']['speed']
    date_time = datetime.now().strftime("%d %b %Y | %I:%M:%S %p")

    print ("-------------------------------------------------------------")
    print ("Weather Stats for - {}  || {}".format(city_name.upper(), date_time))
    print ("-------------------------------------------------------------")

    print ("Current temperature is: {:.2f} deg C".format(temp_city))
    print ("Current weather desc  :",weather_desc)
    print ("Current humidity      :",hmdt, '%')
    print ("Current wind speed    :",wind_spd ,'kmph')
    
current_temperature = temp_city
current_windspeed   = wind_spd
current_humidity    = hmdt
current_weather     = weather_desc
# Out:
# Enter the city name: kuching
# -------------------------------------------------------------
# Weather Stats for - KUCHING  || 01 Jan 2022 | 05:47:02 PM
# -------------------------------------------------------------
# Current temperature is: 26.12 deg C
# Current weather desc  : thunderstorm with light rain
# Current humidity      : 89 %
# Current wind speed    : 1.54 kmph

# %%
#Let's get the city's coordinates (lat and lon)
url = 'https://api.openweathermap.org/data/2.5/weather?q=' + city_name + '&appid=' + api_key

#Let's parse the Json
req = requests.get(url)
data = req.json()

#Let's get the name, the longitude and latitude
name = data['name']
lon = data['coord']['lon']
lat = data['coord']['lat']

#Let's now use the One Call Api to get the 8 day forecast
#We'll need to exclude the minutely and hourly
exclude = "minute,hourly"
url2 = 'https://api.openweathermap.org/data/2.5/onecall?lat='+str(lat)+'&lon='+str(lon)+'&exclude='+'&appid='+api_key

#Let's now parse the JSON
req2 = requests.get(url2)
data2 = req2.json()

#Let's now get the temp for the day, the night and the weather conditions
days = []
nights = []
descr = []
humidity = []
wind_speed = []

import datetime

#Check for today's day
x = datetime.datetime.now()

if (x.strftime("%a") == 'Mon'):
  days_of_week = ['Mon', 'Tue', 'Wed', 'Thu', 'Fri', 'Sat', 'Sun','Mon']
elif (x.strftime("%a") == 'Tue'):
  days_of_week = ['Tue', 'Wed', 'Thu', 'Fri', 'Sat', 'Sun','Mon', 'Tue']
elif (x.strftime("%a") == 'Wed'):
  days_of_week = ['Wed', 'Thu', 'Fri', 'Sat', 'Sun','Mon', 'Tue', 'Wed']
elif (x.strftime("%a") == 'Thu'):
  days_of_week = ['Thu', 'Fri', 'Sat', 'Sun','Mon', 'Tue', 'Wed', 'Thu']
elif (x.strftime("%a") == 'Fri'):
  days_of_week = ['Fri', 'Sat', 'Sun','Mon', 'Tue', 'Wed', 'Thu', 'Fri']
elif (x.strftime("%a") == 'Sat'):
  days_of_week = ['Sat', 'Sun','Mon', 'Tue', 'Wed', 'Thu', 'Fri', 'Sat']
elif (x.strftime("%a") == 'Sun'):
  days_of_week = ['Sun','Mon', 'Tue', 'Wed', 'Thu', 'Fri', 'Sat', 'Sun']


#We need to access 'daily'
for i in data2['daily']:
        
        #We notice that the temperature is in Kelvin, so we need to do -273.15 for every datapoint
        
        #Let's start by days
        #Let's round the decimal numbers to 2
        days.append(round(i['temp']['day'] - 273.15,2))
        
        #Nights
        nights.append(round(i['temp']['night'] - 273.15,2))
        
        #Let's now get the weather condition and the description
        #'weather' [0] 'main' + 'weather' [0] 'description'
        descr.append(i['weather'][0]['main'] + ": " +i['weather'][0]['description'])

        humidity.append(i['humidity'])

        wind_speed.append(i['wind_speed'])
        

#Let's now format the output to make it readable
string = f'[ {name} - 8 days forecast]\n'

#Let's now loop for as much days as there available (8 in this case):
for i in range(len(days)):
    
    #We want to print out the day (day1,2,3,4..)
    #Also, day 1 = today and day 2 = tomorrow for reference
    
    if i == 0:
        string += f'\nDay {i+1} (' + days_of_week[i] + f' - Today)\n'
        
    elif i == 1:
        string += f'\nDay {i+1} (' + days_of_week[i] + f' - Tomorrow)\n'
        
    else:
        string += f'\nDay {i+1} (' + days_of_week[i] + f')\n'
        
    string += 'Morning    :' + str(days[i]) + '°C' + '\n'
    string += 'Night      :' + str(nights[i]) + '°C' + '\n'
    string += 'Conditions :' + descr[i] + '\n'
    string += 'Humidity   :' + str(humidity[i]) + 'g kg-1' + '\n'
    string += 'Wind Speed :' + str(wind_speed[i]) + 'm sec-1' + '\n'
    
print(string)
# Out:
# [ Kuching - 8 days forecast]
#
# Day 1 (Sat - Today)
# Morning    :28.62°C
# Night      :23.77°C
# Conditions :Rain: moderate rain
# Humidity   :77g kg-1
# Wind Speed :2.03m sec-1
#
# Day 2 (Sun - Tomorrow)
# Morning    :25.85°C
# Night      :23.58°C
# Conditions :Rain: moderate rain
# Humidity   :88g kg-1
# Wind Speed :2.02m sec-1
#
# Day 3 (Mon)
# Morning    :27.65°C
# Night      :24.02°C
# Conditions :Rain: moderate rain
# Humidity   :75g kg-1
# Wind Speed :1.39m sec-1
#
# Day 4 (Tue)
# Morning    :28.89°C
# Night      :24.19°C
# Conditions :Rain: light rain
# Humidity   :72g kg-1
# Wind Speed :1.14m sec-1
#
# Day 5 (Wed)
# Morning    :29.54°C
# Night      :24.11°C
# Conditions :Rain: moderate rain
# Humidity   :67g kg-1
# Wind Speed :1.85m sec-1
#
# Day 6 (Thu)
# Morning    :27.64°C
# Night      :24.37°C
# Conditions :Rain: light rain
# Humidity   :80g kg-1
# Wind Speed :2.84m sec-1
#
# Day 7 (Fri)
# Morning    :29.23°C
# Night      :24.4°C
# Conditions :Rain: light rain
# Humidity   :68g kg-1
# Wind Speed :2.64m sec-1
#
# Day 8 (Sat)
# Morning    :28.53°C
# Night      :24.19°C
# Conditions :Rain: light rain
# Humidity   :70g kg-1
# Wind Speed :2.9m sec-1

# %%
#Export as dummy weather csv (weatherForecast.csv)
def createFrame(days_of_week, days, nights, descr, humidity, wind_speed):    
    # To dataframe
    newframe = {'Index'             : [],
                'Day'               : [],
                'MorningTemp'       : [],
                'NightTemp'         : [],
                'Humidity'          : [],
                'WindSpeed'         : [],
                'WeatherPredicted'  : []}
    newframe = pd.DataFrame(newframe)
    
    z = 0
    for x in days_of_week:
        temframe = {'Index'             : [str(z+1)],
                    'Day'               : [days_of_week[z]],
                    'MorningTemp'       : [days[z]],
                    'NightTemp'         : [nights[z]],
                    'Humidity'          : [humidity[z]],
                    'WindSpeed'         : [wind_speed[z]],
                    'WeatherPredicted'  : [descr[z]]}
        z += 1
        temframe = pd.DataFrame(temframe)
        newframe = pd.concat([newframe, temframe])
    
    return newframe

weatherForecast = createFrame(days_of_week, days, nights, descr, humidity, wind_speed)
weatherForecast.to_csv('../dataset/weatherForecast.csv', index = False)
weatherForecast
# Out:
#   Index  Day  MorningTemp  NightTemp  Humidity  WindSpeed     WeatherPredicted
# 0     1  Sat        28.62      23.77      77.0       2.03  Rain: moderate rain
# 0     2  Sun        25.85      23.58      88.0       2.02  Rain: moderate rain
# 0     3  Mon        27.65      24.02      75.0       1.39  Rain: moderate rain
# 0     4  Tue        28.89      24.19      72.0       1.14     Rain: light rain
# 0     5  Wed        29.54      24.11      67.0       1.85  Rain: moderate rain
# 0     6  Thu        27.64      24.37      80.0       2.84     Rain: light rain
# 0     7  Fri        29.23      24.40      68.0       2.64     Rain: light rain
# 0     8  Sat        28.53      24.19      70.0       2.90     Rain: light rain

# %% [markdown]
# # Agricultural Advisor

# %% [markdown]
# To recommend based on dummy weather information.

# %% [markdown]
# ## Building Advisory Dataframe

# %%
import pandas as pd
import numpy as np
import warnings
from sklearn.neighbors import LocalOutlierFactor
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
warnings.filterwarnings('ignore')

# If weatherForecast exist
try:
    df_weather_forecast = pd.read_csv('../dataset/weatherForecast.csv')
except:
    print('weatherForecast.csv File not exist.')
    
# If adviseList exist
try:
    df_advise_list = pd.read_csv('../dataset/adviseList.csv')
except:
    print('adviseList.csv File not exist.')
    
# If suitabilityList exist
try:
    df_advise_list = pd.read_csv('../dataset/suitabilityList.csv')
except:
    print('suitabilityList.csv File not exist.')
    
# To produce: weatherAgriAdvise.csv & plantDoctor.csv
# Out:
# adviseList.csv File not exist.
# suitabilityList.csv File not exist.

# %%
# Stored Weather Info
df_weather_forecast
# Out:
#    Index  Day  MorningTemp  NightTemp  Humidity  WindSpeed  \
# 0      1  Sat        28.62      23.77      77.0       2.03
# 1      2  Sun        25.85      23.58      88.0       2.02
# 2      3  Mon        27.65      24.02      75.0       1.39
# 3      4  Tue        28.89      24.19      72.0       1.14
# 4      5  Wed        29.54      24.11      67.0       1.85
# 5      6  Thu        27.64      24.37      80.0       2.84
# 6      7  Fri        29.23      24.40      68.0       2.64
# 7      8  Sat        28.53      24.19      70.0       2.90
#
#       WeatherPredicted
# 0  Rain: moderate rain
# 1  Rain: moderate rain
# 2  Rain: moderate rain
# 3     Rain: light rain
# 4  Rain: moderate rain
# 5     Rain: light rain
# 6     Rain: light rain
# 7     Rain: light rain

# %%
# Stored Advise Info
# df_advise_list.head(2)

# %%
# Stored Plant Suitability Info
# df_suitability_list.head(2)

# %%
index = df_weather_forecast.iloc[:, 0:1].values 
day = df_weather_forecast.iloc[:, 1:2].values 
MorningTemp = df_weather_forecast.iloc[:, 2:3].values 
NightTemp = df_weather_forecast.iloc[:, 3:4].values 
Humidity = df_weather_forecast.iloc[:, 4:5].values 
WindSpeed = df_weather_forecast.iloc[:, 5:6].values 
Weather = df_weather_forecast.iloc[:, 6:7].values 

# Greater lower logic

# %%
# Create powerAppTemplate.csv
powerAppTemplate = {'Index'            : [],
                    'Day'              : [],
                    'MorningTemp'      : [],
                    'MorningTempChg'   : [],
                    'NightTemp'        : [],
                    'NightTempChg'     : [],
                    'Humidity'         : [],
                    'HumidityChg'      : [],
                    'WindSpeed'        : [],
                    'WindSpeedChg'     : [],
                    'Weather'          : [],
                    'Advise'           : [],
                    'Background'       : []}
powerAppTemplate = pd.DataFrame(powerAppTemplate)

# Create Dummy    
# Weather category: 'Rain', 'Thunderstorm', 'Clouds'
size = len(df_weather_forecast)
dummyTemplate =    {'Index'            : ['1'],
                    'Day'              : ['Sat'],
                    'MorningTemp'      : ['123'],
                    'MorningTempChg'   : ["../resource/image/up.PNG"],
                    'NightTemp'        : ['123'],
                    'NightTempChg'     : ["../resource/image/up.PNG"],
                    'Humidity'         : ['123'],
                    'HumidityChg'      : ["../resource/image/down.PNG"],
                    'WindSpeed'        : ['123'],
                    'WindSpeedChg'     : ["../resource/image/up.PNG"],
                    'Weather'          : ['Clouds:Partial Cloudy'],
                    'Advise'           : ["Advise"],
                    'Background'       : ["../resource/image/PlantingCrops.jpg"]}

dummyTemplate = pd.DataFrame(dummyTemplate)

powerAppTemplate = pd.concat([powerAppTemplate, dummyTemplate])

powerAppTemplate
# Out:
#   Index  Day MorningTemp            MorningTempChg NightTemp  \
# 0     1  Sat         123  ../resource/image/up.PNG       123
#
#                NightTempChg Humidity                 HumidityChg WindSpeed  \
# 0  ../resource/image/up.PNG      123  ../resource/image/down.PNG       123
#
#                WindSpeedChg                Weather  Advise  \
# 0  ../resource/image/up.PNG  Clouds:Partial Cloudy  Advise
#
#                             Background
# 0  ../resource/image/PlantingCrops.jpg

# %% [markdown]
# ["../resource/down.PNG"]
# ![up.PNG](attachment:up.PNG)

# %% [markdown]
# ["../resource/down.PNG"]
# ![down.PNG](attachment:down.PNG)

# %% [markdown]
# ["../resource/PlantingCrops.jpg"]
# ![PlantingCrops.jpg](attachment:PlantingCrops.jpg)

# %% [markdown]
# # Crop Production (including nurseries, greenhouses, forestry)

# %% [markdown]
# Advise generation:
# 1. https://www.epa.gov/agriculture/laws-and-regulations-apply-your-agricultural-operation-farm-activity
# 2. https://www.dosh.gov.my/index.php/legislation/guidelines/agriculture-forestry-fishing/609-03-guidelines-on-occupational-safety-and-health-in-agriculture-2002/file
# 3.https://www.wri.org/insights/4-ways-farmers-can-adapt-climate-change-and-generate-income
# 4.
