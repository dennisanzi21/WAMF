# %% [markdown]
# # Weather Info (temperature, weather, humidity and windspeed)

# %% [markdown]
# To obtain dummy weather information.

# %%
# To obtain weather data 
import requests
import os
from datetime import datetime


#user_api = os.environ['	weather']
api_key = '46eb4ea0e8fadb82e97f406034d68ce5'
city_name = input("Enter the city name: ")

complete_api_link = "https://api.openweathermap.org/data/2.5/weather?q="+city_name+"&appid="+api_key
api_link = requests.get(complete_api_link)
api_data = api_link.json()

if api_data['cod'] == '404':
    print("Invalid City: {}, Please check your City name".format(city_name))
else:
    #create variables to store and display data
    temp_city = ((api_data['main']['temp']) - 273.15)
    weather_desc = api_data['weather'][0]['description']
    hmdt = api_data['main']['humidity']
    wind_spd = api_data['wind']['speed']
    date_time = datetime.now().strftime("%d %b %Y | %I:%M:%S %p")

    print ("-------------------------------------------------------------")
    print ("Weather Stats for - {}  || {}".format(city_name.upper(), date_time))
    print ("-------------------------------------------------------------")

    print ("Current temperature is: {:.2f} deg C".format(temp_city))
    print ("Current weather desc  :",weather_desc)
    print ("Current humidity      :",hmdt, '%')
    print ("Current wind speed    :",wind_spd ,'kmph')
    
current_temperature = temp_city
current_windspeed   = wind_spd
current_humidity    = hmdt
current_weather     = weather_desc
# Out:
# Enter the city name: kuching
# -------------------------------------------------------------
# Weather Stats for - KUCHING  || 08 Jan 2022 | 07:25:01 PM
# -------------------------------------------------------------
# Current temperature is: 28.12 deg C
# Current weather desc  : scattered clouds
# Current humidity      : 78 %
# Current wind speed    : 2.57 kmph

# %%
#Let's get the city's coordinates (lat and lon)
url = 'https://api.openweathermap.org/data/2.5/weather?q=' + city_name + '&appid=' + api_key

#Let's parse the Json
req = requests.get(url)
data = req.json()

#Let's get the name, the longitude and latitude
name = data['name']
lon = data['coord']['lon']
lat = data['coord']['lat']

#Let's now use the One Call Api to get the 8 day forecast
#We'll need to exclude the minutely and hourly
exclude = "minute,hourly"
url2 = 'https://api.openweathermap.org/data/2.5/onecall?lat='+str(lat)+'&lon='+str(lon)+'&exclude='+'&appid='+api_key

#Let's now parse the JSON
req2 = requests.get(url2)
data2 = req2.json()

#Let's now get the temp for the day, the night and the weather conditions
days = []
nights = []
descr = []
humidity = []
wind_speed = []

import datetime

#Check for today's day
x = datetime.datetime.now()

if (x.strftime("%a") == 'Mon'):
  days_of_week = ['Mon - Today', 'Tue - Tomorrow', 'Wed', 'Thu', 'Fri', 'Sat', 'Sun','Mon']
elif (x.strftime("%a") == 'Tue'):
  days_of_week = ['Tue - Today', 'Wed - Tomorrow', 'Thu', 'Fri', 'Sat', 'Sun','Mon', 'Tue']
elif (x.strftime("%a") == 'Wed'):
  days_of_week = ['Wed - Today', 'Thu - Tomorrow', 'Fri', 'Sat', 'Sun','Mon', 'Tue', 'Wed']
elif (x.strftime("%a") == 'Thu'):
  days_of_week = ['Thu - Today', 'Fri - Tomorrow', 'Sat', 'Sun','Mon', 'Tue', 'Wed', 'Thu']
elif (x.strftime("%a") == 'Fri'):
  days_of_week = ['Fri - Today', 'Sat - Tomorrow', 'Sun','Mon', 'Tue', 'Wed', 'Thu', 'Fri']
elif (x.strftime("%a") == 'Sat'):
  days_of_week = ['Sat - Today', 'Sun - Tomorrow','Mon', 'Tue', 'Wed', 'Thu', 'Fri', 'Sat']
elif (x.strftime("%a") == 'Sun'):
  days_of_week = ['Sun - Today','Mon - Tomorrow', 'Tue', 'Wed', 'Thu', 'Fri', 'Sat', 'Sun']


#We need to access 'daily'
for i in data2['daily']:
        
        #We notice that the temperature is in Kelvin, so we need to do -273.15 for every datapoint
        
        #Let's start by days
        #Let's round the decimal numbers to 2
        days.append(round(i['temp']['day'] - 273.15,2))
        
        #Nights
        nights.append(round(i['temp']['night'] - 273.15,2))
        
        #Let's now get the weather condition and the description
        #'weather' [0] 'main' + 'weather' [0] 'description'
        descr.append(i['weather'][0]['main'] + ": " +i['weather'][0]['description'])

        humidity.append(i['humidity'])

        wind_speed.append(i['wind_speed'])
        

#Let's now format the output to make it readable
string = f'[ {name} - 8 days forecast]\n'

#Let's now loop for as much days as there available (8 in this case):
for i in range(len(days)):
    
    #We want to print out the day 1 = today and day 2 = tomorrow for reference
    string += f'\nDay {i+1} (' + days_of_week[i] + f')\n'
        
    string += 'Morning    :' + str(days[i]) + '°C' + '\n'
    string += 'Night      :' + str(nights[i]) + '°C' + '\n'
    string += 'Conditions :' + descr[i] + '\n'
    string += 'Humidity   :' + str(humidity[i]) + 'g kg-1' + '\n'
    string += 'Wind Speed :' + str(wind_speed[i]) + 'm sec-1' + '\n'
    
print(string)
# Out:
# [ Kuching - 8 days forecast]
#
# Day 1 (Sat - Today)
# Morning    :28.67°C
# Night      :25.27°C
# Conditions :Rain: light rain
# Humidity   :74g kg-1
# Wind Speed :1.89m sec-1
#
# Day 2 (Sun - Tomorrow)
# Morning    :28.16°C
# Night      :24.58°C
# Conditions :Rain: moderate rain
# Humidity   :78g kg-1
# Wind Speed :1.67m sec-1
#
# Day 3 (Mon)
# Morning    :28.08°C
# Night      :24.63°C
# Conditions :Rain: moderate rain
# Humidity   :80g kg-1
# Wind Speed :1.95m sec-1
#
# Day 4 (Tue)
# Morning    :26.25°C
# Night      :23.81°C
# Conditions :Rain: moderate rain
# Humidity   :88g kg-1
# Wind Speed :1.91m sec-1
#
# Day 5 (Wed)
# Morning    :23.32°C
# Night      :23.88°C
# Conditions :Rain: heavy intensity rain
# Humidity   :99g kg-1
# Wind Speed :2.18m sec-1
#
# Day 6 (Thu)
# Morning    :25.47°C
# Night      :23.36°C
# Conditions :Rain: moderate rain
# Humidity   :92g kg-1
# Wind Speed :1.91m sec-1
#
# Day 7 (Fri)
# Morning    :24.52°C
# Night      :22.51°C
# Conditions :Rain: heavy intensity rain
# Humidity   :94g kg-1
# Wind Speed :2.1m sec-1
#
# Day 8 (Sat)
# Morning    :26.77°C
# Night      :23.9°C
# Conditions :Rain: light rain
# Humidity   :78g kg-1
# Wind Speed :1.47m sec-1

# %%
#Export as dummy weather csv (weatherForecast.csv)
def createFrame(days_of_week, days, nights, descr, humidity, wind_speed):    
    # To dataframe
    newframe = {'Index'             : [],
                'Day'               : [],
                'MorningTemp'       : [],
                'NightTemp'         : [],
                'Humidity'          : [],
                'WindSpeed'         : [],
                'Weather'  : []}
    newframe = pd.DataFrame(newframe)
    
#     z = 0
#     for x in days_of_week:
#         temframe = {'Index'             : [str(z+1)],
#                     'Day'               : [days_of_week[z]],
#                     'MorningTemp'       : [days[z]],
#                     'NightTemp'         : [nights[z]],
#                     'Humidity'          : [humidity[z]],
#                     'WindSpeed'         : [wind_speed[z]],
#                     'Weather'           : [descr[z]]}
#         z += 1
#         temframe = pd.DataFrame(temframe)
#         newframe = pd.concat([newframe, temframe])
    
    return newframe

weatherForecast = createFrame(days_of_week, days, nights, descr, humidity, wind_speed)
weatherForecast.to_csv('../dataset/weatherForecast.csv', index = False)
weatherForecast
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_18224/2069762126.py in <module>
#      26     return newframe
#      27
# ---> 28 weatherForecast = createFrame(days_of_week, days, nights, descr, humidity, wind_speed)
#      29 weatherForecast.to_csv('../dataset/weatherForecast.csv', index = False)
#      30 weatherForecast
#
# ~\AppData\Local\Temp/ipykernel_18224/2069762126.py in createFrame(days_of_week, days, nights, descr, humidity, wind_speed)
#       9                 'WindSpeed'         : [],
#      10                 'Weather'  : []}
# ---> 11     newframe = pd.DataFrame(newframe)
#      12
#      13     z = 0
#
# NameError: name 'pd' is not defined

# %% [markdown]
# # Climate Suitability Plant Suggestion

# %%
# #Export as plant suggestion based on climate csv (weatherForecast.csv)
# def createClimateSuitabilityFrame(days_of_week, days, nights, descr, humidity, wind_speed):    
#     # To dataframe
#     newframe = {'Index'             : [],
#                 'Plant'             : [],
#                 'Germination'       : [],
#                 'DaysToMaturity'    : [],
#                 'Harvest'           : []}
#     newframe = pd.DataFrame(newframe)
    
#     z = 0
#     for x in days_of_week:
#         temframe = {'Index'             : [str(z+1)],
#                     'Day'               : [days_of_week[z]],
#                     'MorningTemp'       : [days[z]],
#                     'NightTemp'         : [nights[z]],
#                     'Humidity'          : [humidity[z]],
#                     'WindSpeed'         : [wind_speed[z]],
#                     'Weather'           : [descr[z]]}
#         z += 1
#         temframe = pd.DataFrame(temframe)
#         newframe = pd.concat([newframe, temframe])
    
#     return newframe

# weatherForecast = createFrame(days_of_week, days, nights, descr, humidity, wind_speed)
# weatherForecast.to_csv('../dataset/weatherForecast.csv', index = False)
# weatherForecast

# %%
import pandas as pd

#Export as plant suggestion based on climate csv (weatherForecast.csv)
def createClimateSuitabilityFrame():    
    # To dataframe
    newframe = {'Index'             : [],
                'Plant'             : [],
                'Germination'       : [],
                'DaysToMaturity'    : [],
                'Harvest'           : []}
    newframe = pd.DataFrame(newframe)
    
    return newframe

newframe = createClimateSuitabilityFrame()
newframe.to_csv('../dataset/newframe.csv', index = False)
newframe
# Out:
# Empty DataFrame
# Columns: [Index, Plant, Germination, DaysToMaturity, Harvest]
# Index: []

# %% [markdown]
# # Agriculture Advise List

# %%
# To create dummy agriculture advise list
adviseList = pd.read_csv('../dataset/adviseList.csv')
adviseList.head(5)

# to provide situational advice based on crop selected and their initiation data
# /----- to do
# DaysToMaturity 
# ------/
# Out:
#    Index              Weather  \
# 0      0     Rain: light rain
# 1      1     Rain: light rain
# 2      2  Rain: moderate rain
# 3      3  Rain: moderate rain
# 4      4     Rain: heavy rain
#
#                                               Advise  \
# 0  Wear the proper footwear to avoid exposing you...
# 1  Prepare equipment such as using fabric plant c...
# 2             Watch out the water level before going
# 3  Wear protective equipment to protect ourselves...
# 4  Fungicide spray programmes should be maintaine...
#
#                                           Precaution  \
# 0  Protect farm equipment from rain, especially t...
# 1  Keep your crops away from rain to avoid microb...
# 2  Make Sure water areas are fenced like dams, we...
# 3  Spray animals frequently for removal of ectopa...
# 4  Keep an eye out for flare-ups of diseases such...
#
#                                                Image
# 0  https://drive.google.com/drive/folders/1fCbave...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN

# %% [markdown]
# # Plant Album

# %%
# To create dummy plant album
plantAlbum = pd.read_csv('../dataset/plantAlbum.csv')
# plantAlbum.to_csv('../dataset/plantAlbum.csv', index = True)
# plantAlbum = pd.read_csv('../dataset/plantAlbum.csv')
# plantAlbum = plantAlbum.rename(columns={'Unnamed: 0':'Index'})
# plantAlbum.to_csv('../dataset/plantAlbum.csv', index = False)
plantAlbum.head(5)
# Out:
#    Index        Plant AlternatePlantName  \
# 0      0        Basil                NaN
# 1      1     Beetroot              Beets
# 2      2       Borage   Burrage, Bugloss
# 3      3  Broad beans          Fava bean
# 4      4     Broccoli                NaN
#
#                                                Image  \
# 0  https://drive.google.com/file/d/1g5Qt4D5XWCo5m...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                                      GrowInstruction  \
# 0  Grow in seed trays, and plant out in 4-6 weeks...
# 1  Easy to grow. Sow in garden. Sow seed at a dep...
# 2  Easy to grow. Sow in garden. Sow seed at a dep...
# 3  Easy to grow. Sow in garden. Sow seed at a dep...
# 4  Easy to grow. Grow in seed trays, and plant ou...
#
#                           GrowthSpace  \
# 0   Space plants: 8 - 10 inches apart
# 1   Space plants: 8 - 12 inches apart
# 2        Space plants: 8 inches apart
# 3   Space plants: 6 - 10 inches apart
# 4  Space plants: 14 - 20 inches apart
#
#                                      HarvestDuration  \
# 0     Harvest in 10-12 weeks. Pick before flowering.
# 1                             Harvest in 7-10 weeks.
# 2  Harvest in 8-10 weeks. Use leaves before flowe...
# 3  Harvest in 12-22 weeks. Pick frequently to enc...
# 4  Harvest in 10-16 weeks. Cut flowerhead off wit...
#
#                                      CompatiblePlant  \
# 0          Compatible with (can grow beside): Tomato
# 1  Compatible with (can grow beside): Onions, Sil...
# 2  Compatible with (can grow beside): Strawberry,...
# 3  Compatible with (can grow beside): Dill, Potatoes
# 4  Compatible with (can grow beside): Dwarf (bush...
#
#                                    IncompatiblePlant  \
# 0                                                NaN
# 1  Avoid growing close to: Asparagus, Carrots, Sw...
# 2                                                NaN
# 3                                                NaN
# 4  Avoid growing close to: Climbing (pole) beans,...
#
#                                       AdditionalInfo  \
# 0  Basil is commonly used fresh in cooked recipes...
# 1  Apart from boiling whole for salads, beetroot ...
# 2  Has a slight cucumber taste which goes well in...
# 3  The fresh beans are eaten steamed or boiled. A...
# 4  The stem (peeled), leaves, and flowerhead are ...
#
#                                        Unnamed: 9
# 0                                             NaN
# 1                                             NaN
# 2                                             NaN
# 3  Will freeze well. Remove from pods and blanch.
# 4                                             NaN

# %% [markdown]
# # Plant Nursary

# %%
# # To create dummy plant nursary log book
# plantNursery = pd.read_csv('../dataset/plantNursery.csv')
# plantNursery

# %% [markdown]
# # Agricultural Advisor

# %% [markdown]
# To recommend based on dummy weather information.

# %% [markdown]
# ## Building Advisory Dataframe

# %%
import pandas as pd
import numpy as np
import warnings
from sklearn.neighbors import LocalOutlierFactor
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
warnings.filterwarnings('ignore')

# If weatherForecast exist
try:
    df_weather_forecast = pd.read_csv('../dataset/weatherForecast.csv')
except:
    print('weatherForecast.csv File not exist.')
    
# If adviseList exist
try:
    df_advise_list = pd.read_csv('../dataset/adviseList.csv')
except:
    print('adviseList.csv File not exist.')
    
# If sayurStatistic exist
try:
    df_sayur_Statistic = pd.read_excel('../dataset/sayurStatistic.xlsx', sheet_name=None)
    
except:
    print('sayurStatistic.xlsx File not exist.')
    
# If plantnursury exist
try:
    df_plant_nursery = pd.read_csv('../dataset/plantNursery.csv')
except:
    print('plantNursery.csv File not exist.')
    
# Outcomes: weatherAgriAdvise.csv, plantAlbum.csv, sayurStatistic.csv and plantDoctor.csv
# Out:
# plantNursery.csv File not exist.

# %%
df_advise_list
# Out:
#     Index              Weather  \
# 0       0     Rain: light rain
# 1       1     Rain: light rain
# 2       2  Rain: moderate rain
# 3       3  Rain: moderate rain
# 4       4     Rain: heavy rain
# 5       5         Thunderstorm
# 6       6         Thunderstorm
# 7       7         Thunderstorm
# 8       8               Clouds
# 9       9               Clouds
# 10     10               Clouds
#
#                                                Advise  \
# 0   Wear the proper footwear to avoid exposing you...
# 1   Prepare equipment such as using fabric plant c...
# 2              Watch out the water level before going
# 3   Wear protective equipment to protect ourselves...
# 4   Fungicide spray programmes should be maintaine...
# 5                 Watch out for\nflashes of lightning
# 6                     Check the shelter once 3 months
# 7   Best not to feed plants as the rootballs canno...
# 8   Wear light-colored clothing to prevent heat st...
# 9                    Monitor temperature and humidity
# 10  Wear a protective mask while pulling them out ...
#
#                                            Precaution  \
# 0   Protect farm equipment from rain, especially t...
# 1   Keep your crops away from rain to avoid microb...
# 2   Make Sure water areas are fenced like dams, we...
# 3   Spray animals frequently for removal of ectopa...
# 4   Keep an eye out for flare-ups of diseases such...
# 5    Canceling or postponing outdoor activities early
# 6   Look out for water leakage in the animal shelt...
# 7   The muddy covering will halt photosynthesis be...
# 8   Avoid gardening during the sun’s peak hours, 1...
# 9   Water vegetable gardens early in the day when ...
# 10  The spread of invasive plants such as ragweed,...
#
#                                                 Image
# 0   https://drive.google.com/drive/folders/1fCbave...
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN

# %%
weatherAgriAdvise = pd.merge(df_weather_forecast, df_advise_list, on='Weather')
weatherAgriAdvise = weatherAgriAdvise.drop(columns=['Index_y', 'Index_x'])
weatherAgriAdvise.to_csv('../dataset/weatherAgriAdvise.csv', index = False)
weatherAgriAdvise.head(5)
# Out:
#            Day  MorningTemp  NightTemp  Humidity  WindSpeed  \
# 0  Mon - Today        30.04      24.03      65.0       2.88
# 1  Mon - Today        30.04      24.03      65.0       2.88
# 2          Wed        30.07      24.20      66.0       2.22
# 3          Wed        30.07      24.20      66.0       2.22
# 4          Thu        27.99      23.90      79.0       1.74
#
#                Weather                                             Advise  \
# 0  Rain: moderate rain             Watch out the water level before going
# 1  Rain: moderate rain  Wear protective equipment to protect ourselves...
# 2  Rain: moderate rain             Watch out the water level before going
# 3  Rain: moderate rain  Wear protective equipment to protect ourselves...
# 4  Rain: moderate rain             Watch out the water level before going
#
#                                           Precaution Image
# 0  Make Sure water areas are fenced like dams, we...   NaN
# 1  Spray animals frequently for removal of ectopa...   NaN
# 2  Make Sure water areas are fenced like dams, we...   NaN
# 3  Spray animals frequently for removal of ectopa...   NaN
# 4  Make Sure water areas are fenced like dams, we...   NaN

# %%
# df_sayur_Statistic = pd.read_excel('../dataset/sayurStatisticSarawak.xlsx', sheet_name=None)
# df_sayur_Statistic = pd.DataFrame(df_sayur_Statistic)

# df_sayur_Statistic

# %% [markdown]
# # Crop Production (including nurseries, greenhouses, forestry)

# %% [markdown]
# Advise generation:
# 1. https://www.epa.gov/agriculture/laws-and-regulations-apply-your-agricultural-operation-farm-activity
# 2. https://www.dosh.gov.my/index.php/legislation/guidelines/agriculture-forestry-fishing/609-03-guidelines-on-occupational-safety-and-health-in-agriculture-2002/file
# 3.https://www.wri.org/insights/4-ways-farmers-can-adapt-climate-change-and-generate-income
# 4.
